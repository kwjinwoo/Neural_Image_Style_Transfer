# %%
from utils import *
import cv2
import matplotlib.pyplot as plt

# %%
style_path = "./imgs/style2.jpg"
content_path = "./imgs/content.jpg"

content_img, style_img, gen_img = img_preprocessing(content_path, style_path)

# %%
img = deprocess_image(content_img.numpy())
img = img[..., ::-1]
plt.imshow(img)

# %%
img = deprocess_image(style_img.numpy())
img = img[..., ::-1]
plt.imshow(img)
